# %%
from qiskit_ibm_runtime import QiskitRuntimeService
 
QiskitRuntimeService.save_account(
  token="vBqxd_olXJoKQtYR1sKBMuapRJ_3v0_27vNkfiCnH2d0", # Use the 44-character API_KEY you created and saved from the IBM Quantum Platform Home dashboard
  name="main_school", # Optional
  instance="crn:v1:bluemix:public:quantum-computing:us-east:a/fa5c6534bd224a988857c7232f44f11e:220b0133-16ef-4699-b0b6-a10ea08507a2::", # Optional
  set_as_default=True, # Optional
  overwrite=True, # Optional
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
